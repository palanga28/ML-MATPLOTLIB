# %% [markdown]
#  import torch
# import os
# import cv2
# import numpy as np

# %%
vec = torch.tensor([1,2,3,4,5,5,5])
vec.shape
# Out:
# torch.Size([7])

# %%
mat = torch.tensor([[]])
mat.shape
# Out:
# torch.Size([1, 0])

# %%
van = torch.tensor ([[[[[1]]]]])
van.shape
# Out:
# torch.Size([1, 1, 1, 1, 1])

# %% [markdown]
# ##type de donnees

# %%
t3 = torch.tensor([3.4])
t3.dtype
# Out:
# torch.float32

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 t4_8 = t4.to(torch.int16)
#       2 t4_8.dtype
#
# NameError: name 't4' is not defined

# %%
t4= torch.tensor([3])
t4.dtype
# Out:
# torch.int64

# %%
t4_8 = t4.to(torch.int16)
t4_8.dtype
# Out:
# torch.int16
